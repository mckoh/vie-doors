# %%
from pandas import DataFrame
from viedoors import FMLoader, NPALoader


obj = "420"

npa = NPALoader(file=f"data/{obj}/npa.xlsx", title="NPA")
fm = FMLoader()

df_npa = npa.get_data(prefixed=True)
df_fm = fm.get_data(prefixed=True)

# %%
# NPA___schlossernummer
# FM___bauteil + FM___ebene + FM___topnr

# %%
df_npa["fm-npa-merge"] = df_npa["NPA___schlossernummer"].map()
# Out:
#     NPA___objekt NPA___ebene NPA___bauteil NPA___aks_plan NPA___aks_real  \
# 0            420          K1             A        2205.01      keine Nr.
# 1            420          K1             A        2506.01      keine Nr.
# 2            420          K1             A        2308.01      keine Nr.
# 3            420          K1             A        2108.01      keine Nr.
# 4            420          K1             A        1305.02      keine Nr.
# ..           ...         ...           ...            ...            ...
# 734          420          02             A        0226.02      Keine Nr.
# 735          420          DA             A        0216.01        0216.01
# 736          420          DA             A        0213.02        0213.02
# 737          420          DA             A        0213.01        0213.01
# 738          420          DA             A        0714.01      keine Nr.
#
#     NPA___alte_tuernummer NPA___schlossernummer NPA___hoehe_cm  \
# ...

# %%
df_fm.head(2)
# Out:
#   FM___bauteil FM___ebene FM___topnr FM___brandmelderkette FM___brandmeldernr  \
# 0          063         K1          1                  UZ11                NaN
# 1          063         K1          2                  UZ11                NaN
#
#   FM___erfasst_von FM___tuer_12flg FM___zugaengigkeit FM___ok FM___hersteller  \
# 0          Traxler             NaN                NaN     NaN             NaN
# 1          Traxler             NaN                NaN     NaN             NaN
#
#    ... FM___tax FM___gesuanbot FM___arbeitszeit FM___material  \
# 0  ...      NaN              1                1             1
# 1  ...      NaN              1                1             1
#
#   FM___schadensmeldung FM___aufnahme FM___kleinregie_summe FM___zyklus  \
# 0                    0             0                     0         589
# 1                    0             0                     0         589
#
#   FM___integration_aks merge
# 0                  NaN   NaN
# ...
