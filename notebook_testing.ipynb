# %%
from viedoors import ExcelLoader

e = ExcelLoader(file_name="134_gesamt_20241212.xlsx", file_path="data", title="CAD")
e.get_data(prefixed=True)
# Out:
# Loading of file '134_gesamt_20241212.xlsx' completed.
# Data has 14 columns an 404 rows.
#                 CAD___name CAD___gar_turnummer_bauteil  \
# 0    GAR-61-Turnummer-2013                         134
# 1    GAR-61-Turnummer-2013                         134
# 2    GAR-61-Turnummer-2013                         134
# 3    GAR-61-Turnummer-2013                         134
# 4    GAR-61-Turnummer-2013                         134
# ..                     ...                         ...
# 399  GAR-61-Turnummer-2013                         134
# 400  GAR-61-Turnummer-2013                         134
# 401  GAR-61-Turnummer-2013                         134
# 402  GAR-61-Turnummer-2013                         134
# 403  GAR-61-Turnummer-2013                         134
#
#     CAD___gar_turnummer_ebene CAD___gar_turnummer_modul  \
# 0                          00                         A
# 1                          00                         A
# ...

# %%
e = ExcelLoader(file_name="NPA_Tuer Aufnahme Obj420.xlsx", file_path="data", title="CAD")
e.get_data(prefixed=True)
# Out:
# Loading of file 'NPA_Tuer Aufnahme Obj420.xlsx' completed.
# Data has 24 columns an 114 rows.
#     CAD___objekt CAD___ebene CAD___bauteil CAD___aks_plan CAD___aks_real  \
# 0            420         K 1             A        2205.01      keine Nr.
# 1            420         K 1             A        2506.01      keine Nr.
# 2            420         K 1             A        2308.01      keine Nr.
# 3            420         K 1             A        2108.01      keine Nr.
# 4            420         K 1             A        1305.02      keine Nr.
# ..           ...         ...           ...            ...            ...
# 109          420          02             A        0226.02      Keine Nr.
# 110          420          DA             A        0216.01        0216.01
# 111          420          DA             A        0213.02        0213.02
# 112          420          DA             A        0213.01        0213.01
# 113          420          DA             A        0714.01      keine Nr.
# ...

# %%
e = ExcelLoader(file_name="BSTüren_Filemaker_11.04.22.xlsx", file_path="data", title="CAD")
# Out:
# Loading of file 'BSTüren_Filemaker_11.04.22.xlsx' completed.
# Data has 160 columns an 6438 rows.
#      CAD___bauteil CAD___ebene CAD___topnr CAD___brandmelderkette  \
# 0              063           K           1                   UZ11
# 1              063           K           2                   UZ11
# 2              063           K           3                    NaN
# 3              063           K           4                   UZ11
# 4              063           K           5                   UZ11
# ...            ...         ...         ...                    ...
# 6433           988           0           6                    NaN
# 6434           988           1           2                    NaN
# 6435           988           1           3                    NaN
# 6436           988           1           4                    NaN
# 6437           988           1           5                    NaN
#
#      CAD___brandmeldernr CAD___erfasst_von CAD___tuer_12flg  \
# ...

# %%
list(e.get_data(prefixed=True).columns)
# Out:
# ['CAD___bauteil',
#  'CAD___ebene',
#  'CAD___topnr',
#  'CAD___brandmelderkette',
#  'CAD___brandmeldernr',
#  'CAD___erfasst_von',
#  'CAD___tuer_12flg',
#  'CAD___zugaengigkeit',
#  'CAD___ok',
#  'CAD___hersteller',
#  'CAD___tuerblattmaterial',
#  'CAD___masse_durchglichte',
#  'CAD___tuerschliessertype',
#  'CAD___schliessfolgeregler',
#  'CAD___offenhaltevorrichtung',
#  'CAD___verriegelungstflg',
#  'CAD___baenderart',
#  'CAD___baenderanzahl',
#  'CAD___baendermaterial',
#  'CAD___drueckertype',
#  'CAD___drueckermaterial',
#  'CAD___schlossart',
#  'CAD___schlossfunktion',
#  'CAD___tuererfassungsdatum',
#  'CAD___wartungsdatum',
#  'CAD___reparaturdatum',
#  'CAD___repdurchfgvon',
#  'CAD___wartdurchfgvon',
#  'CAD___m29',
#  'CAD___arbeitscode',
#  'CAD___materialcode',
#  'CAD___nettopreis',
#  'CAD___einheit',
#  'CAD___vk1',
#  'CAD___einh',
#  'CAD___vk11',
#  'CAD___nettopr',
#  'CAD___summarb',
#  'CAD___summmat',
#  'CAD___nettosummearb',
#  'CAD___mwst',
# ...
