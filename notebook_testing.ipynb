# %%
from viedoors import ExcelLoader

e = ExcelLoader(file_name="134_gesamt_20241212.xlsx", file_path="data", title="CAD")
e.get_data(prefixed=True)
# Out:
# Loading of file '134_gesamt_20241212.xlsx' completed.
# Data has 14 columns an 404 rows.
#                 CAD___name CAD___gar-turnummer-bauteil  \
# 0    GAR-61-Turnummer-2013                         134
# 1    GAR-61-Turnummer-2013                         134
# 2    GAR-61-Turnummer-2013                         134
# 3    GAR-61-Turnummer-2013                         134
# 4    GAR-61-Turnummer-2013                         134
# ..                     ...                         ...
# 399  GAR-61-Turnummer-2013                         134
# 400  GAR-61-Turnummer-2013                         134
# 401  GAR-61-Turnummer-2013                         134
# 402  GAR-61-Turnummer-2013                         134
# 403  GAR-61-Turnummer-2013                         134
#
#     CAD___gar-turnummer-ebene CAD___gar-turnummer-modul  \
# 0                          00                         A
# 1                          00                         A
# 2                          00                         A
# 3                          00                         A
# 4                          00                         A
# ..                        ...                       ...
# 399                        K1                         A
# 400                        K1                         A
# 401                        K1                         A
# 402                        K1                         A
# 403                        K1                         A
#
#     CAD___gar-turnummer-aks-nr CAD___gar-turnummer-nummer  \
# 0                         0641                         01
# 1                         0710                         01
# 2                         0711                         01
# 3                         0713                         01
# 4                         0722                         01
# ..                         ...                        ...
# 399                       5114                         01
# 400                       5151                         01
# 401                       5314                         01
# 402                       5551                         01
# 403                       5740                         01
#
#     CAD___gar-turnummer-alt CAD___gar-fluchttuernummer CAD___gar-tur-breite  \
# 0                      005A                        NaN                  NaN
# 1                       ---                        NaN                  NaN
# 2                       ---                        NaN                  NaN
# 3                       ---                        NaN                  NaN
# 4                 0A0722.01                        NaN                   85
# ..                      ...                        ...                  ...
# 399                      75                        NaN                  130
# 400                      09                        NaN                  100
# 401                      76                        NaN                  130
# 402                      10                        NaN                  100
# 403                      48                          2                  140
#
#     CAD___gar-tur-hohe CAD___gar-bsk CAD___gar-hel CAD___gar-sec  \
# 0                  NaN          NEIN           ---           ---
# 1                  NaN          NEIN           ---           ---
# 2                  NaN          NEIN           ---           ---
# 3                  NaN          NEIN           ---           ---
# 4                  210          NEIN           ---           ---
# ..                 ...           ...           ...           ...
# 399                200          NEIN            Ja           ---
# 400                200           T30          Nein           ---
# 401                200          NEIN            Ja           ---
# 402               200T          NEIN          Nein           ---
# 403                200          NEIN          Nein           ---
#
#     CAD___gar-zusatz-1
# 0                  ---
# 1                  ---
# 2                  ---
# 3                  ---
# 4                  ---
# ..                 ...
# 399                ---
# 400                ---
# 401                ---
# 402                ---
# 403                ---
#
# [404 rows x 14 columns]
